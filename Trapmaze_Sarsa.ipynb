# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 初期位置での迷路の様子

fig = plt.figure(figsize=(10, 10))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 2], [1, 1], color='red', linewidth=2)
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([2, 2], [5, 4], color='red', linewidth=2)
plt.plot([1, 2], [3, 3], color='red', linewidth=2)
plt.plot([1, 1], [4, 3], color='red', linewidth=2)
plt.plot([1, 4], [2, 2], color='red', linewidth=2)
plt.plot([4, 4], [2, 3], color='red', linewidth=2)
plt.plot([3, 3], [2, 1], color='red', linewidth=2)
plt.plot([3, 4], [4, 4], color='red', linewidth=2)
plt.plot([4, 4], [0, 1], color='red', linewidth=2)
rect = plt.Rectangle((4,1),1,1,fc="#90ee90")
ax.add_patch(rect)



# 状態を示す文字S0～S24を描く
plt.text(0.5, 4.5, 'S0', size=14, ha='center')
plt.text(1.5, 4.5, 'S1', size=14, ha='center')
plt.text(2.5, 4.5, 'S2', size=14, ha='center')
plt.text(3.5, 4.5, 'S3', size=14, ha='center')
plt.text(4.5, 4.5, 'S4', size=14, ha='center')
plt.text(0.5, 3.5, 'S5', size=14, ha='center')
plt.text(1.5, 3.5, 'S6', size=14, ha='center')
plt.text(2.5, 3.5, 'S7', size=14, ha='center')
plt.text(3.5, 3.5, 'S8', size=14, ha='center')
plt.text(4.5, 3.5, 'S9', size=14, ha='center')
plt.text(0.5, 2.5, 'S10', size=14, ha='center')
plt.text(1.5, 2.5, 'S11', size=14, ha='center')
plt.text(2.5, 2.5, 'S12', size=14, ha='center')
plt.text(3.5, 2.5, 'S13', size=14, ha='center')
plt.text(4.5, 2.5, 'S14', size=14, ha='center')
plt.text(0.5, 1.5, 'S15', size=14, ha='center')
plt.text(1.5, 1.5, 'S16', size=14, ha='center')
plt.text(2.5, 1.5, 'S17', size=14, ha='center')
plt.text(3.5, 1.5, 'S18', size=14, ha='center')
plt.text(4.5, 1.5, 'S19', size=14, ha='center')
plt.text(0.5, 0.5, 'S20', size=14, ha='center')
plt.text(1.5, 0.5, 'S21', size=14, ha='center')
plt.text(2.5, 0.5, 'S22', size=14, ha='center')
plt.text(3.5, 0.5, 'S23', size=14, ha='center')
plt.text(4.5, 0.5, 'S24', size=14, ha='center')
plt.text(0.5, 4.3, 'START', ha='center')
plt.text(4.5, 0.25, 'GOAL', ha='center')

ax.set_xlim(0, 5)
ax.set_ylim(0, 5)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

line, = ax.plot([0.5], [4.5], marker="o", color='g', markersize=70)

# トラップ仕掛ける
plt.plot([2.2, 2.85], [4.85, 4.2], color='grey', linewidth=4)
plt.plot([2.2, 2.85], [4.2, 4.85], color='grey', linewidth=4)

# %%
# 行は状態0～24、列は移動方向で↑、→、↓、←を表す

theta_0 = np.array([[np.nan, 1, 1, np.nan],
                    [np.nan, np.nan, 1, 1],
                    [np.nan, 1, 1, np.nan],
                    [np.nan, 1, np.nan, 1],
                    [np.nan, np.nan, 1, 1],
                    [1, np.nan, 1, np.nan],
                    [1, 1, np.nan, np.nan],
                    [1, 1, 1, 1],
                    [np.nan, 1, 1, 1],
                    [1, np.nan, 1, 1],
                    [1, 1, 1, np.nan],
                    [np.nan, 1, np.nan, 1],
                    [1, 1, np.nan, 1],
                    [1, np.nan, np.nan, 1],
                    [1, np.nan, 1, np.nan],
                    [1, 1, 1, np.nan],
                    [np.nan, 1, np.nan, 1],
                    [np.nan, np.nan, 1, 1],
                    [np.nan, 1, 1, np.nan],
                    [1, np.nan, 1, 1],
                    [1, np.nan, np.nan, np.nan],
                    [np.nan, 1, np.nan, np.nan],
                    [1, 1, np.nan, 1],
                    [1, np.nan, np.nan, 1], #※s24はゴールなので、方策はなし
                    ])

# %%
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''

    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :]) 

    pi = np.nan_to_num(pi)

    return pi

# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# 初期の行動価値関数Qを設定

[a, b] = theta_0.shape
Q = np.random.rand(a, b) * theta_0

# %%
# ε-greedy法を実装


def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 行動を決める
    if np.random.rand() < epsilon:
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        next_direction = direction[np.nanargmax(Q[s, :])]

    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action


def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]

    # 行動から次の状態を決める
    if next_direction == "up":
        s_next = s - 5
    elif next_direction == "right":
        s_next = s + 1
    elif next_direction == "down":
        s_next = s + 5
    elif next_direction == "left":
        s_next = s - 1

    return s_next

# %%
# Sarsaによる行動価値関数Qの更新


def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):

    if s_next == 24:
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])

    return Q

# %%
# Sarsaで迷路を解く関数の定義、状態と行動の履歴および更新したQを出力


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0
    a = a_next = get_action(s, Q, epsilon, pi)
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):
        a = a_next

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 24:
            r = 1
            a_next = np.nan
        elif s_next == 2:
            r = -100
            s_next = 0
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます

        Q = Sarsa(s, a, r, s_next, a_next, Q, eta, gamma)

        # 終了判定
        if s_next == 24:
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Sarsaで迷路を解く

eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1

while is_continue:
    print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Sarsaで迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値の変化を出力
    v = new_v

    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")

    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 1.2548734751959607
# 迷路を解くのにかかったステップ数は114です
# エピソード:2
# 2.1890355075301624
# 迷路を解くのにかかったステップ数は198です
# エピソード:3
# 0.49842296345886516
# 迷路を解くのにかかったステップ数は64です
# エピソード:4
# 0.36502406273454874
# 迷路を解くのにかかったステップ数は20です
# エピソード:5
# 0.1914320199028639
# 迷路を解くのにかかったステップ数は14です
# エピソード:6
# 0.19315500823893317
# 迷路を解くのにかかったステップ数は16です
# エピソード:7
# 0.16258493979118582
# 迷路を解くのにかかったステップ数は14です
# エピソード:8
# 0.14920247753165694
# 迷路を解くのにかかったステップ数は14です
# エピソード:9
# 0.13640023030267506
# 迷路を解くのにかかったステップ数は14です
# エピソード:10
# 0.1270860000451826
# 迷路を解くのにかかったステップ数は14です
# エピソード:11
# 0.10562096790627679
# 迷路を解くのにかかったステップ数は12です
# エピソード:12
# 0.1148641005941653
# 迷路を解くのにかかったステップ数は14です
# エピソード:13
# 0.09627197001972865
# 迷路を解くのにかかったステップ数は12です
# エピソード:14
# 0.10541510455410519
# 迷路を解くのにかかったステップ数は14です
# エピソード:15
# 0.0877713331019861
# 迷路を解くのにかかったステップ数は12です
# エピソード:16
# 0.08430267571987271
# 迷路を解くのにかかったステップ数は12です
# エピソード:17
# 0.08093068681824195
# 迷路を解くのにかかったステップ数は12です
# エピソード:18
# 0.07764550193257713
# 迷路を解くのにかかったステップ数は12です
# エピソード:19
# 0.0744385647429418
# 迷路を解くのにかかったステップ数は12です
# エピソード:20
# 0.07130274871979325
# 迷路を解くのにかかったステップ数は12です
# エピソード:21
# 0.08118370116197876
# 迷路を解くのにかかったステップ数は14です
# エピソード:22
# 0.06777250216285702
# 迷路を解くのにかかったステップ数は12です
# エピソード:23
# 0.06599789641842257
# 迷路を解くのにかかったステップ数は12です
# エピソード:24
# 0.0641395924715572
# 迷路を解くのにかかったステップ数は12です
# エピソード:25
# 0.0622131924263955
# 迷路を解くのにかかったステップ数は12です
# エピソード:26
# 0.06023299481773148
# 迷路を解くのにかかったステップ数は12です
# エピソード:27
# 0.058742707874695654
# 迷路を解くのにかかったステップ数は12です
# エピソード:28
# 0.05768590113837507
# 迷路を解くのにかかったステップ数は12です
# エピソード:29
# 0.06682593840483309
# 迷路を解くのにかかったステップ数は14です
# エピソード:30
# 0.051430650888142304
# 迷路を解くのにかかったステップ数は12です
# エピソード:31
# 0.4433387529492886
# 迷路を解くのにかかったステップ数は78です
# エピソード:32
# 0.056315479958533254
# 迷路を解くのにかかったステップ数は14です
# エピソード:33
# 0.061782648031939
# 迷路を解くのにかかったステップ数は16です
# エピソード:34
# 0.05443581774329492
# 迷路を解くのにかかったステップ数は14です
# エピソード:35
# 0.05754509188855578
# 迷路を解くのにかかったステップ数は16です
# エピソード:36
# 0.05714054553102771
# 迷路を解くのにかかったステップ数は16です
# エピソード:37
# 0.05762397651151019
# 迷路を解くのにかかったステップ数は16です
# エピソード:38
# 0.04674993129234045
# 迷路を解くのにかかったステップ数は14です
# エピソード:39
# 0.045228675267892704
# 迷路を解くのにかかったステップ数は14です
# エピソード:40
# 0.052715957353100584
# 迷路を解くのにかかったステップ数は16です
# エピソード:41
# 0.043943948671784805
# 迷路を解くのにかかったステップ数は14です
# エピソード:42
# 0.042497999225341254
# 迷路を解くのにかかったステップ数は14です
# エピソード:43
# 0.04155753291405223
# 迷路を解くのにかかったステップ数は14です
# エピソード:44
# 0.04903026595977594
# 迷路を解くのにかかったステップ数は16です
# エピソード:45
# 0.039518952617566716
# 迷路を解くのにかかったステップ数は14です
# エピソード:46
# 0.03364012854375803
# 迷路を解くのにかかったステップ数は12です
# エピソード:47
# 0.03886098384747727
# 迷路を解くのにかかったステップ数は14です
# エピソード:48
# 0.03702308912093516
# 迷路を解くのにかかったステップ数は14です
# エピソード:49
# 0.029676601529051938
# 迷路を解くのにかかったステップ数は12です
# エピソード:50
# 0.0294241533038343
# 迷路を解くのにかかったステップ数は12です
# エピソード:51
# 0.03348682603884018
# 迷路を解くのにかかったステップ数は14です
# エピソード:52
# 0.03057521022034404
# 迷路を解くのにかかったステップ数は12です
# エピソード:53
# 0.022666325114669983
# 迷路を解くのにかかったステップ数は10です
# エピソード:54
# 0.031470045652975565
# 迷路を解くのにかかったステップ数は14です
# エピソード:55
# 0.02165302639265665
# 迷路を解くのにかかったステップ数は10です
# エピソード:56
# 0.026504235295454592
# 迷路を解くのにかかったステップ数は12です
# エピソード:57
# 0.024147710143123058
# 迷路を解くのにかかったステップ数は12です
# エピソード:58
# 0.019863917271995213
# 迷路を解くのにかかったステップ数は10です
# エピソード:59
# 0.024485065645764192
# 迷路を解くのにかかったステップ数は12です
# エピソード:60
# 0.019089134982651856
# 迷路を解くのにかかったステップ数は10です
# エピソード:61
# 0.01827984419731482
# 迷路を解くのにかかったステップ数は10です
# エピソード:62
# 0.017473483169774873
# 迷路を解くのにかかったステップ数は10です
# エピソード:63
# 0.017039068029812532
# 迷路を解くのにかかったステップ数は10です
# エピソード:64
# 0.016600882524014815
# 迷路を解くのにかかったステップ数は10です
# エピソード:65
# 0.01614943772363653
# 迷路を解くのにかかったステップ数は10です
# エピソード:66
# 0.01568630820155753
# 迷路を解くのにかかったステップ数は10です
# エピソード:67
# 0.015213121272847019
# 迷路を解くのにかかったステップ数は10です
# エピソード:68
# 0.014731530877916565
# 迷路を解くのにかかったステップ数は10です
# エピソード:69
# 0.014243195164850286
# 迷路を解くのにかかったステップ数は10です
# エピソード:70
# 0.013749757377757799
# 迷路を解くのにかかったステップ数は10です
# エピソード:71
# 0.013252829697531665
# 迷路を解くのにかかったステップ数は10です
# エピソード:72
# 0.012894583305604501
# 迷路を解くのにかかったステップ数は10です
# エピソード:73
# 0.012637868163314192
# 迷路を解くのにかかったステップ数は10です
# エピソード:74
# 0.012373972037392544
# 迷路を解くのにかかったステップ数は10です
# エピソード:75
# 0.012103480524887689
# 迷路を解くのにかかったステップ数は10です
# エピソード:76
# 0.011827033699821132
# 迷路を解くのにかかったステップ数は10です
# エピソード:77
# 0.011545311547431714
# 迷路を解くのにかかったステップ数は10です
# エピソード:78
# 0.01125902123017991
# 迷路を解くのにかかったステップ数は10です
# エピソード:79
# 0.010968886000424172
# 迷路を解くのにかかったステップ数は10です
# エピソード:80
# 0.010675635593034694
# 迷路を解くのにかかったステップ数は10です
# エピソード:81
# 0.01037999794756339
# 迷路を解くのにかかったステップ数は10です
# エピソード:82
# 0.01008269212416385
# 迷路を解くのにかかったステップ数は10です
# エピソード:83
# 0.009855209751354732
# 迷路を解くのにかかったステップ数は10です
# エピソード:84
# 0.009753472218101411
# 迷路を解くのにかかったステップ数は10です
# エピソード:85
# 0.009643895516181056
# 迷路を解くのにかかったステップ数は10です
# エピソード:86
# 0.009526927913073802
# 迷路を解くのにかかったステップ数は10です
# エピソード:87
# 0.009403021484748864
# 迷路を解くのにかかったステップ数は10です
# エピソード:88
# 0.009272630542346505
# 迷路を解くのにかかったステップ数は10です
# エピソード:89
# 0.00913621004946047
# 迷路を解くのにかかったステップ数は10です
# エピソード:90
# 0.008994214054890037
# 迷路を解くのにかかったステップ数は10です
# エピソード:91
# 0.008847094161563485
# 迷路を解くのにかかったステップ数は10です
# エピソード:92
# 0.008695298048655487
# 迷路を解くのにかかったステップ数は10です
# エピソード:93
# 0.008539268060663074
# 迷路を解くのにかかったステップ数は10です
# エピソード:94
# 0.008379439874347527
# 迷路を解くのにかかったステップ数は10です
# エピソード:95
# 0.00821624125194137
# 迷路を解くのにかかったステップ数は10です
# エピソード:96
# 0.008050090886807193
# 迷路を解くのにかかったステップ数は10です
# エピソード:97
# 0.00788139734583898
# 迷路を解くのにかかったステップ数は10です
# エピソード:98
# 0.00771055811121224
# 迷路を解くのにかかったステップ数は10です
# エピソード:99
# 0.007537958722667271
# 迷路を解くのにかかったステップ数は10です
# エピソード:100
# 0.007363972020269116
# 迷路を解くのにかかったステップ数は10です

# %%
# 最終的な方策を確認
np.set_printoptions(precision=3, suppress=True)
print(Q)
# Out:
# [[  nan   nan 0.33    nan]
#  [  nan   nan   nan 0.286]
#  [  nan 0.284 0.403   nan]
#  [  nan 0.347   nan   nan]
#  [  nan   nan 0.376 0.815]
#  [0.099   nan 0.379   nan]
#  [0.742   nan   nan   nan]
#  [  nan 0.648 0.493 0.467]
#  [  nan 0.694 0.619 0.694]
#  [0.792   nan 0.657 0.33 ]
#  [0.377 0.377 0.439   nan]
#  [  nan 0.038   nan 0.376]
#  [0.95  0.049   nan 0.345]
#  [0.952   nan   nan 0.278]
#  [0.545   nan 0.585   nan]
#  [0.119 0.505 0.391   nan]
#  [  nan 0.575   nan 0.363]
#  [  nan   nan 0.649 0.095]
#  [  nan 0.9   0.396   nan]
#  [0.389   nan 1.    0.544]
#  [0.15    nan   nan   nan]
#  [  nan 0.358   nan   nan]
#  [0.235 0.726   nan 0.36 ]
#  [0.809   nan   nan 0.034]]

# %%
# エージェントの移動の様子を可視化
from matplotlib import animation
from IPython.display import HTML


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 5) + 0.5  # 状態のx座標は、5で割った余り+0.5
    y = 4.5 - int(state / 5)  # y座標は5で割った商を4.5から引く
    line.set_data(x, y)
    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# /var/folders/8z/fkj2n4xj3_lgyrrsc71xvtvm0000gn/T/ipykernel_61823/330215667.py:17: MatplotlibDeprecationWarning: Setting data with a non sequence type is deprecated since 3.7 and will be remove two minor releases later
#   line.set_data(x, y)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdd20f157af2c42f8b14f78e191e0d3e0">
#   <div class="anim-controls">
#     <input id="_anim_sliderdd20f157af2c42f8b14f78e191e0d3e0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdd20f157af2c42f8b14f78e191e0d3e0.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animdd20f157af2c42f8b14f78e191e0d3e0.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectdd20f157af2c42f8b14f78e191e0d3e0"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_dd20f157af2c42f8b14f78e191e0d3e0"
#              checked>
#       <label for="_anim_radio1_dd20f157af2c42f8b14f78e191e0d3e0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_dd20f157af2c42f8b14f78e191e0d3e0"
#              >
#       <label for="_anim_radio2_dd20f157af2c42f8b14f78e191e0d3e0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_dd20f157af2c42f8b14f78e191e0d3e0"
#              >
#       <label for="_anim_radio3_dd20f157af2c42f8b14f78e191e0d3e0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdd20f157af2c42f8b14f78e191e0d3e0";
#     var slider_id = "_anim_sliderdd20f157af2c42f8b14f78e191e0d3e0";
#     var loop_select_id = "_anim_loop_selectdd20f157af2c42f8b14f78e191e0d3e0";
#     var frames = new Array(11);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8pXeV/AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAB/Y0lEQ
